# %%
import pickle
import pandas as pd
import os
os.path.abspath(os.getcwd())
# Out:
# '/c/Users/oanacletojun/Documents/temp/clv-cpa-retention-curves/survival_curves/data'

# %%
pd.read_pickle('REGION')
# Out:
#                        RATE_WEEK01_cum  RATE_WEEK02_cum  RATE_WEEK03_cum  \
# REGION
# Americas                             1         0.537078         0.110068
# Arab, Africa and Asia                1         0.442120         0.313870
# Europe 1 and AU                      1         0.741422         0.383803
# Europe 2                             1         0.696858         0.466597
#
#                        RATE_WEEK04_cum  RATE_WEEK05_cum  RATE_WEEK06_cum  \
# REGION
# Americas                      0.050820         0.056440         0.039280
# Arab, Africa and Asia         0.140776         0.102633         0.080054
# Europe 1 and AU               0.332939         0.251752         0.221591
# Europe 2                      0.342816         0.265542         0.229357
#
#                        RATE_WEEK07_cum  RATE_WEEK08_cum  RATE_WEEK09_cum  \
# REGION
# Americas                      0.037657         0.032760         0.028017
# ...

# %%
with open('REGION', 'rb') as f:
    loaded_obj = pickle.load(f)

print(loaded_obj)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-160f6e74edd7> in <module>
#       1 with open('REGION', 'rb') as f:
# ----> 2     loaded_obj = pickle.load(f)
#       3
#       4 print(loaded_obj)
#       5
#
# ModuleNotFoundError: No module named 'pandas.core.internals.managers'; 'pandas.core.internals' is not a package
